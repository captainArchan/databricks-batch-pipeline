# %%
# %run "./utils/database"

# %%
# create_schema("project_batch_streaming")
# create_volume(volumn_name="books", schema_name="project_batch_streaming")
# if(is_file_in_current_path("books", "csv")):

print(
    process_data_to_volumn(
        volume_name = "books",
        schema_name = "project_batch_streaming",
        file_name = "books",
        file_type = "csv"  
    )
)
